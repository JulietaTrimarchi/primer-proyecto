# %%
# Importo librería a utilizar

import pandas as pd

# %%
# Abro Dataset Movies

dataset_movies = pd.read_csv("C:/Users/Juli/Desktop/Data Science/Proyecto individual I Machine Learning/Datasets originales/movies_dataset.csv",
                                delimiter=',',
                                quotechar='"',
                                escapechar='\\',
                                low_memory = False)

#Informacion del Dataset

dataset_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
dataset_movies.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
# Convierto los datos de tipo objeto a flotante de la columna budget

dataset_movies['budget'] = pd.to_numeric(dataset_movies['budget'], errors='coerce')
dataset_movies["budget"]
# Out:
# 0        30000000.0
# 1        65000000.0
# 2               0.0
# 3        16000000.0
# 4               0.0
#             ...
# 45461           0.0
# 45462           0.0
# 45463           0.0
# 45464           0.0
# 45465           0.0
# Name: budget, Length: 45466, dtype: float64

# %%
# Transformo nulos en "0" en columnas budget y revenue
dataset_movies[['budget', 'revenue']] = dataset_movies[['budget', 'revenue']].fillna(0)

# Verifico
print(dataset_movies[['budget', 'revenue']].isnull().sum())
# Out:
# budget     0
# revenue    0
# dtype: int64

# %%
# Convierto a formato datetime la columna release_date

dataset_movies['release_date'] = pd.to_datetime(dataset_movies['release_date'], errors='coerce', format='%Y-%m-%d')
dataset_movies["release_date"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 45466 entries, 0 to 45465
# Series name: release_date
# Non-Null Count  Dtype
# --------------  -----
# 45376 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 355.3 KB

# %%
# Transformo las fechas a formato AAAA-mm-dd
dataset_movies['release_date'] = dataset_movies['release_date'].dt.strftime('%Y-%m-%d')

# Elimino los valores nulos
dataset_movies = dataset_movies.dropna(subset=['release_date'])

# Verifico
print(dataset_movies['release_date'].isnull().sum())
# Out:
# 0

# %%
# Creo columna que contiene el año de estreno de cada película
dataset_movies['release_year'] = pd.to_datetime(dataset_movies['release_date']).dt.year

# %%
# Importo numpy
import numpy as np

# Creo la columna return con el cociente entre revenue y budget

dataset_movies['return'] = np.where(dataset_movies['budget'] == 0, 0, dataset_movies['revenue'] / dataset_movies['budget'])

dataset_movies[["revenue","budget","return"]].head()
# Out:
#        revenue      budget     return
# 0  373554033.0  30000000.0  12.451801
# 1  262797249.0  65000000.0   4.043035
# 2          0.0         0.0   0.000000
# 3   81452156.0  16000000.0   5.090760
# 4   76578911.0         0.0   0.000000

# %%
# Elimino columnas que no usaré
dataset_movies = dataset_movies.drop(['video','imdb_id','adult','original_title','poster_path','homepage'], axis=1)

# Chequeo cantidad de columnas

num_columns = dataset_movies.shape[1]
print(num_columns)
# Out:
# 20

# %%
dataset_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45376 entries, 0 to 45465
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4488 non-null   object
#  1   budget                 45376 non-null  float64
#  2   genres                 45376 non-null  object
#  3   id                     45376 non-null  object
#  4   original_language      45365 non-null  object
#  5   overview               44435 non-null  object
#  6   popularity             45376 non-null  object
#  7   production_companies   45376 non-null  object
#  8   production_countries   45376 non-null  object
#  9   release_date           45376 non-null  object
#  10  revenue                45376 non-null  float64
#  11  runtime                45130 non-null  float64
#  12  spoken_languages       45376 non-null  object
#  13  status                 45296 non-null  object
# ...

# %%
# Recortaré el Dataset Movies y armaré un dataframe que sirva para la primer consulta de la API

# %%
# Importo libreria que me será util 

import calendar

# Agrego una columna con los meses de estreno de cada película

dataset_movies['release_month'] = pd.to_datetime(dataset_movies['release_date']).dt.month
dataset_movies
# Out:
#                                    belongs_to_collection      budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1                                                    NaN  65000000.0
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0.0
# 3                                                    NaN  16000000.0
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0.0
# ...                                                  ...         ...
# 45460                                                NaN         0.0
# 45462                                                NaN         0.0
# 45463                                                NaN         0.0
# 45464                                                NaN         0.0
# 45465                                                NaN         0.0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# ...

# %%
# Creo un diccioario para los nombres de los meses en español

meses_español = {   1: 'enero',
                    2: 'febrero',
                    3: 'marzo',
                    4: 'abril',
                    5: 'mayo',
                    6: 'junio',
                    7: 'julio',
                    8: 'agosto',
                    9: 'septiembre',
                    10: 'octubre',
                    11: 'noviembre',
                    12: 'diciembre'
}

dataset_movies['name_month'] = dataset_movies['release_month'].map(meses_español)
dataset_movies
# Out:
#                                    belongs_to_collection      budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1                                                    NaN  65000000.0
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0.0
# 3                                                    NaN  16000000.0
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0.0
# ...                                                  ...         ...
# 45460                                                NaN         0.0
# 45462                                                NaN         0.0
# 45463                                                NaN         0.0
# 45464                                                NaN         0.0
# 45465                                                NaN         0.0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# ...

# %%
print(dataset_movies['release_year'].min())
print(dataset_movies['release_year'].max())
# Out:
# 1874
# 2020

# %%
# Creo una copia del dataframe

data_mes = dataset_movies.copy()

# %%
# Voy a realizar un filtro sobre el mismo para obtener las columnas titulo y mes de estreno.

data_mes = data_mes[['title', 'name_month']]
data_mes
# Out:
#                              title name_month
# 0                        Toy Story    octubre
# 1                          Jumanji  diciembre
# 2                 Grumpier Old Men  diciembre
# 3                Waiting to Exhale  diciembre
# 4      Father of the Bride Part II    febrero
# ...                            ...        ...
# 45460                   Robin Hood       mayo
# 45462          Century of Birthing  noviembre
# 45463                     Betrayal     agosto
# 45464             Satan Triumphant    octubre
# 45465                     Queerama      junio
#
# [45376 rows x 2 columns]

# %%
# Voy a crear un Dataframe que contenga el mes y el total de películas estrenadas

# Conteo de películas por mes
conteo_peliculas = data_mes.groupby('name_month').size().reset_index(name='total_movies')


# Lista de meses en el orden correcto
meses_orden = ['enero', 'febrero', 'marzo', 'abril', 'mayo', 'junio', 'julio', 'agosto', 'septiembre', 'octubre', 'noviembre', 'diciembre']

# Creo un DataFrame con los meses en el orden correcto
df_mes_orden = pd.DataFrame(meses_orden, columns=['name_month'])

# Merge para asegurar que todos los meses estén presentes y con un conteo de 0 si no hay películas
df_resultado = df_mes_orden.merge(conteo_peliculas, on='name_month', how='left').fillna(0).astype({'total_movies': 'int'})

print("\nDataFrame Final con el Conteo de Películas por Mes:")
print(df_resultado)
# Out:
# DataFrame Final con el Conteo de Películas por Mes:
#     name_month  total_movies
# 0        enero          5912
# 1      febrero          3032
# 2        marzo          3553
# 3        abril          3453
# 4         mayo          3339
# 5        junio          3153
# 6        julio          2640
# 7       agosto          3394
# 8   septiembre          4838
# 9      octubre          4615
# 10   noviembre          3661
# 11   diciembre          3786

# %%
# Verifico si la suma de la columna peliculas totales coincide con la cantidad de filas (que coincide con cantidad de películas) y sabiendo que no hay valores nulos.
print(df_resultado['total_movies'].sum())

# Noto que coincide con el total de filas.

df_resultado
# Out:
# 45376
#     name_month  total_movies
# 0        enero          5912
# 1      febrero          3032
# 2        marzo          3553
# 3        abril          3453
# 4         mayo          3339
# 5        junio          3153
# 6        julio          2640
# 7       agosto          3394
# 8   septiembre          4838
# 9      octubre          4615
# 10   noviembre          3661
# 11   diciembre          3786

# %%
# Almaceno el Dataframe en un archivo con formato Parquet y es el que utilizaremos para la primer consulta de la API

df_resultado.to_parquet('Peliculas por mes', engine='pyarrow')

# %%
# Crearé un Dataframe que sirva para la segunda consulta de la API

# Transformo la columna de fecha de estreno en formato datetime y luego obtengo el día de la semana en inglés.
dataset_movies['release_date'] = pd.to_datetime(dataset_movies['release_date'])
dataset_movies['release_day'] = dataset_movies['release_date'].dt.day_name()

# Diccionario para traducir días de la semana al español
traduccion_dias = {
    'Monday': 'lunes',
    'Tuesday': 'martes',
    'Wednesday': 'miercoles',
    'Thursday': 'jueves',
    'Friday': 'viernes',
    'Saturday': 'sabado',
    'Sunday': 'domingo'
}

# Traduzco el día de la semana al español
dataset_movies['release_day'] = dataset_movies['release_day'].map(traduccion_dias)

# Creo el nuevo DataFrame con las columnas deseadas
df_dia = dataset_movies[['title', 'release_day']]

print("\nNuevo DataFrame con Títulos y Días de la Semana en Español:")
print(df_dia)
# Out:
# Nuevo DataFrame con Títulos y Días de la Semana en Español:
#                              title release_day
# 0                        Toy Story       lunes
# 1                          Jumanji     viernes
# 2                 Grumpier Old Men     viernes
# 3                Waiting to Exhale     viernes
# 4      Father of the Bride Part II     viernes
# ...                            ...         ...
# 45460                   Robin Hood       lunes
# 45462          Century of Birthing      jueves
# 45463                     Betrayal     viernes
# 45464             Satan Triumphant     domingo
# 45465                     Queerama     viernes
#
# [45376 rows x 2 columns]

# %%
# Contaré el número de películas en cada día de la semana
conteo = df_dia.groupby('release_day').size().reset_index(name='total_peliculas')


# Lista de días de la semana en el orden correcto
dias_semana_orden = ['lunes', 'martes', 'miercoles', 'jueves', 'viernes', 'sabado', 'domingo']

#Creo un DataFrame con los días de la semana en el orden correcto
df_dias_orden = pd.DataFrame(dias_semana_orden, columns=['release_day'])

# Merge para asegurar que todos los días de la semana estén presentes y con un conteo de 0 si no hay películas
df_dia = df_dias_orden.merge(conteo, on='release_day', how='left').fillna(0).astype({'total_peliculas': 'int'})

print("\nDataFrame Final con el Conteo de Películas por Día de la Semana:")
print(df_dia)
# Out:
# DataFrame Final con el Conteo de Películas por Día de la Semana:
#   release_day  total_peliculas
# 0       lunes             3503
# 1      martes             4641
# 2   miercoles             7035
# 3      jueves             7525
# 4     viernes            13908
# 5      sabado             5151
# 6     domingo             3613

# %%
# Verifico que sea correcto el paso anterior. La suma del total de peliculas coincide con la cantidad de filas, es decir, con la cantidad total de peliculas.
df_dia['total_peliculas'].sum()
# Out:
# np.int64(45376)

# %%
# Almaceno el Dataframe en un archivo con formato Parquet y es el que utilizaremos para la segunda consulta de la API

df_dia.to_parquet('Peliculas por dia', engine='pyarrow')

# %%
# Creo un Dataframe para la tercera consulta de la API

# Voy a realizar un filtro sobre el Dataframe Movies para obtener las columnas titulo,año de estreno y el score (popularity)
df_score = dataset_movies[['title', 'release_year','popularity']]
df_score
# Out:
#                              title  release_year popularity
# 0                        Toy Story          1995  21.946943
# 1                          Jumanji          1995  17.015539
# 2                 Grumpier Old Men          1995    11.7129
# 3                Waiting to Exhale          1995   3.859495
# 4      Father of the Bride Part II          1995   8.387519
# ...                            ...           ...        ...
# 45460                   Robin Hood          1991   5.683753
# 45462          Century of Birthing          2011   0.178241
# 45463                     Betrayal          2003   0.903007
# 45464             Satan Triumphant          1917   0.003503
# 45465                     Queerama          2017   0.163015
#
# [45376 rows x 3 columns]

# %%
# Almaceno el Dataframe en un archivo con formato Parquet y es el que utilizaremos para la tercer consulta de la API

df_score.to_parquet('Score', engine='pyarrow')

# %%
# Creo un dataframe que sirva para la cuarta consulta de la API

df_votos = dataset_movies[['title','vote_count','vote_average']]
df_votos
# Out:
#                              title  vote_count  vote_average
# 0                        Toy Story      5415.0           7.7
# 1                          Jumanji      2413.0           6.9
# 2                 Grumpier Old Men        92.0           6.5
# 3                Waiting to Exhale        34.0           6.1
# 4      Father of the Bride Part II       173.0           5.7
# ...                            ...         ...           ...
# 45460                   Robin Hood        26.0           5.7
# 45462          Century of Birthing         3.0           9.0
# 45463                     Betrayal         6.0           3.8
# 45464             Satan Triumphant         0.0           0.0
# 45465                     Queerama         0.0           0.0
#
# [45376 rows x 3 columns]

# %%
# Almaceno el Dataframe en un archivo con formato Parquet y es el que utilizaremos para la cuarta consulta de la API

df_votos.to_parquet('Votos', engine='pyarrow')

# %%
# Desanidaré los datos de la columna genre para poder utilizarlos en el EDA

# Realizo una copia de movies_dataset
data_movies = dataset_movies.copy()

# %%
# Importo librería necesaria
import json

# Creo una función para limpiar y convertir cadenas a JSON
def convert_to_json(text:str)->list:

    """Convierte una cadena de texto en formato JSON a una lista de diccionarios.

    Args:
        text (str): Cadena de texto que representa una lista de diccionarios en formato JSON.

    Returns:
        list: Lista de diccionarios representada en la cadena JSON. Si ocurre un error durante la conversión, se devuelve una lista vacía.
    """
    
    json_text = text.replace("'", '"')
    try:
        # Intenta cargar la cadena como JSON
        return json.loads(json_text)
    
    except json.JSONDecodeError as e:
        print(f"Error al decodificar JSON: {e}")
        return []

# Aplico la función a la columna 'genres'
data_movies['genres'] = data_movies['genres'].apply(convert_to_json)

# %%
# Crearé una función con el fin de crear una columna que contenga sólo los generos asociados a cada película

def extract_genre_names(genre_list: list[dict[str, str]]) -> str:

    """Extrae los nombres de géneros de una lista de diccionarios y los une en una cadena.

    Args:
        genre_list (list[dict[str, str]]): Lista de diccionarios donde cada diccionario representa un género de película

    Returns:
        str: Cadena de texto con los nombres de los géneros separados por comas. Si la lista está vacía o ningún diccionario contiene la clave 'name', se devuelve una cadena vacía.
    """
    
    return ', '.join(genres['name'] for genres in genre_list if 'name' in genres)

data_movies['genres_names'] = data_movies['genres'].apply(extract_genre_names)

print(data_movies['genres_names'])
# Out:
# 0         Animation, Comedy, Family
# 1        Adventure, Fantasy, Family
# 2                   Romance, Comedy
# 3            Comedy, Drama, Romance
# 4                            Comedy
#                     ...
# 45460        Drama, Action, Romance
# 45462                         Drama
# 45463       Action, Drama, Thriller
# 45464
# 45465
# Name: genres_names, Length: 45376, dtype: object

# %%
import ast

def convert_to_list_of_dicts(text:str)->list[dict[str, str]]:

    """Convierte una cadena que representa una lista de diccionarios en una lista de diccionarios de Python.

    Args:
        text (str): Una cadena que representa una lista de diccionarios.

    Returns:
        list[dict[str, str]]: Una lista de diccionarios. 
    """

    try:
        # Utilizo ast.literal_eval para convertir la cadena a una lista de diccionarios
        return ast.literal_eval(text)
    except (ValueError, SyntaxError) as e:
        print(f"Error al evaluar el texto: {e}")
        return []

# Aplico la función a la columna 'cast'
data_movies['spoken_languages'] = data_movies['spoken_languages'].apply(convert_to_list_of_dicts)


# Verifico el tipo de datos de las columnas
print(data_movies['spoken_languages'].apply(type).value_counts())
# Out:
# spoken_languages
# <class 'list'>    45376
# Name: count, dtype: int64

# %%
# Crearé una función con el fin de crear una columna que contenga sólo los idiomas hablandos en cada película

def extract_languages(languages_list: list[dict[str, str]]) -> str:

    """Extrae los idiomas de una lista de diccionarios y los une en una cadena.

    Args:
        languages_list (list[dict[str, str]]): Lista de diccionarios donde cada diccionario tiene información de los idiomas de la película.

    Returns:
        str: Cadena de texto con los idiomas separados por comas. Si la lista está vacía o ningún diccionario contiene la clave 'name', se devuelve una cadena vacía.
    """
    
    return ', '.join(spoken_languages['name'] for spoken_languages in languages_list if 'name' in spoken_languages)

data_movies['languages_names'] = data_movies['spoken_languages'].apply(extract_genre_names)

print(data_movies['languages_names'])
# Out:
# 0                  English
# 1        English, Français
# 2                  English
# 3                  English
# 4                  English
#                ...
# 45460              English
# 45462
# 45463              English
# 45464
# 45465              English
# Name: languages_names, Length: 45376, dtype: object

# %%
# Voy a eliminar columnas que no considero pertinentes para el posterior analisis EDA

data_movies = data_movies.drop(columns=['belongs_to_collection','budget','genres','production_countries','revenue','runtime','status','tagline','release_date','return','release_day','release_month','name_month','production_companies','spoken_languages','languages_names'])
data_movies
# Out:
#            id original_language  \
# 0         862                en
# 1        8844                en
# 2       15602                en
# 3       31357                en
# 4       11862                en
# ...       ...               ...
# 45460   30840                en
# 45462  111109                tl
# 45463   67758                en
# 45464  227506                en
# 45465  461257                en
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 45460  Yet another version of the classic epic, with ...   5.683753
# ...

# %%
#Abro Dataset Credits
dataset_credits = pd.read_csv("C:/Users/Juli/Desktop/Data Science/Proyecto individual I Machine Learning/Datasets originales/credits.csv")

#Informacion del Dataset
dataset_credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45476 non-null  object
#  1   crew    45476 non-null  object
#  2   id      45476 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB

# %%
dataset_credits
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# ...

# %%
# Desanidaré los datos de la columna cast y crew para que luego me sirva para el informe EDA

# Realizo una copia de dataset_credits
data_credits = dataset_credits.copy()

# %%
import ast

def convert_to_list_of_dicts(text:str)->list[dict[str, str]]:

    """Convierte una cadena que representa una lista de diccionarios en una lista de diccionarios de Python.

    Args:
        text (str): Una cadena que representa una lista de diccionarios.

    Returns:
        list[dict[str, str]]: Una lista de diccionarios. 
    """

    try:
        # Utilizo ast.literal_eval para convertir la cadena a una lista de diccionarios
        return ast.literal_eval(text)
    except (ValueError, SyntaxError) as e:
        print(f"Error al evaluar el texto: {e}")
        return []

# Aplico la función a la columna 'cast'
data_credits['cast'] = data_credits['cast'].apply(convert_to_list_of_dicts)

# Aplico la función a la columna 'crew'
data_credits['crew'] = data_credits['crew'].apply(convert_to_list_of_dicts)

# Verifico el tipo de datos de las columnas
print(data_credits['cast'].apply(type).value_counts())
print(data_credits['crew'].apply(type).value_counts())
# Out:
# cast
# <class 'list'>    45476
# Name: count, dtype: int64
# crew
# <class 'list'>    45476
# Name: count, dtype: int64

# %%
# Crearé una función con el fin de crear una columna que contenga sólo los nombres de actores asociados a cada película

def extract_names(cast_list: list[dict[str, str]]) -> str:

    """Extrae los nombres de actores de una lista de diccionarios y los une en una cadena.

    Args:
        cast_list (list[dict[str, str]]): Lista de diccionarios donde cada diccionario tiene información de cada actor de la película

    Returns:
        str: Cadena de texto con los nombres de los actores separados por comas. Si la lista está vacía o ningún diccionario contiene la clave 'name', se devuelve una cadena vacía.
    """
    
    return ', '.join(cast['name'] for cast in cast_list if 'name' in cast)

data_credits['actors_names'] = data_credits['cast'].apply(extract_genre_names)

print(data_credits['actors_names'])
# Out:
# 0        Tom Hanks, Tim Allen, Don Rickles, Jim Varney,...
# 1        Robin Williams, Jonathan Hyde, Kirsten Dunst, ...
# 2        Walter Matthau, Jack Lemmon, Ann-Margret, Soph...
# 3        Whitney Houston, Angela Bassett, Loretta Devin...
# 4        Steve Martin, Diane Keaton, Martin Short, Kimb...
#                                ...
# 45471            Leila Hatami, Kourosh Tahami, Elham Korda
# 45472    Angel Aquino, Perry Dizon, Hazel Orencio, Joel...
# 45473    Erika Eleniak, Adam Baldwin, Julie du Page, Ja...
# 45474    Iwan Mosschuchin, Nathalie Lissenko, Pavel Pav...
# 45475
# Name: actors_names, Length: 45476, dtype: object

# %%
# Crearé una función con el fin de crear una columna que contenga sólo los nombres de los directores asociados a cada película

def extract_names_directors(crew_list: list[dict[str, str]]) -> str:

    """Extrae los nombres de directores de una lista de diccionarios y los une en una cadena.

    Args:
        crew_list (list[dict[str, str]]): Lista de diccionarios donde cada diccionario tiene información de cada miembro del equipo de la película

    Returns:
        str: Nombre del director. Si la lista está vacía o ningún diccionario contiene la clave 'Directing', se devuelve una cadena vacía.
    """
    
    # Filtra los diccionarios para obtener solo aquellos cuyo 'job' es 'Director'
    directors = [crew['name'] for crew in crew_list if crew.get('job') == 'Director']
    # Une los nombres de los directores en una sola cadena, separados por comas
    return ', '.join(directors)

data_credits['directors_names'] = data_credits['crew'].apply(extract_names_directors)
print(data_credits['directors_names'])
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 45471    Hamid Nematollah
# 45472            Lav Diaz
# 45473      Mark L. Lester
# 45474    Yakov Protazanov
# 45475       Daisy Asquith
# Name: directors_names, Length: 45476, dtype: object

# %%
# Voy a borrar las columnas cast y crew 

data_credits = data_credits.drop(columns=['cast', 'crew'])
data_credits
# Out:
#            id                                       actors_names  \
# 0         862  Tom Hanks, Tim Allen, Don Rickles, Jim Varney,...
# 1        8844  Robin Williams, Jonathan Hyde, Kirsten Dunst, ...
# 2       15602  Walter Matthau, Jack Lemmon, Ann-Margret, Soph...
# 3       31357  Whitney Houston, Angela Bassett, Loretta Devin...
# 4       11862  Steve Martin, Diane Keaton, Martin Short, Kimb...
# ...       ...                                                ...
# 45471  439050          Leila Hatami, Kourosh Tahami, Elham Korda
# 45472  111109  Angel Aquino, Perry Dizon, Hazel Orencio, Joel...
# 45473   67758  Erika Eleniak, Adam Baldwin, Julie du Page, Ja...
# 45474  227506  Iwan Mosschuchin, Nathalie Lissenko, Pavel Pav...
# 45475  461257
#
#         directors_names
# 0         John Lasseter
# 1          Joe Johnston
# 2         Howard Deutch
# 3       Forest Whitaker
# 4         Charles Shyer
# ...                 ...
# 45471  Hamid Nematollah
# 45472          Lav Diaz
# ...

# %%
# Ambos dataframes transformados los voy a almacenar en formato parquet para utilizarlos en el EDA

transformado_movies = data_movies.to_parquet('Movies Transformado', engine='pyarrow')
transformado_credits = data_credits.to_parquet('Credits Transformado', engine='pyarrow')
